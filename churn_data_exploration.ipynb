# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
churn = pd.read_csv('train.csv')
data_description = pd.read_csv('data_descriptions.csv')

# %%
data_description
# Out:
#                  Column_name Column_type Data_type  \
# 0                 AccountAge     Feature   integer
# 1             MonthlyCharges     Feature     float
# 2               TotalCharges     Feature     float
# 3           SubscriptionType     Feature    object
# 4              PaymentMethod     Feature    string
# 5           PaperlessBilling     Feature    string
# 6                ContentType     Feature    string
# 7          MultiDeviceAccess     Feature    string
# 8           DeviceRegistered     Feature    string
# 9        ViewingHoursPerWeek     Feature     float
# 10    AverageViewingDuration     Feature     float
# 11  ContentDownloadsPerMonth     Feature   integer
# 12           GenrePreference     Feature    string
# 13                UserRating     Feature     float
# 14    SupportTicketsPerMonth     Feature   integer
# 15                    Gender     Feature    string
# 16             WatchlistSize     Feature     float
# ...

# %%
churn.columns.values
# Out:
# array(['AccountAge', 'MonthlyCharges', 'TotalCharges', 'SubscriptionType',
#        'PaymentMethod', 'PaperlessBilling', 'ContentType',
#        'MultiDeviceAccess', 'DeviceRegistered', 'ViewingHoursPerWeek',
#        'AverageViewingDuration', 'ContentDownloadsPerMonth',
#        'GenrePreference', 'UserRating', 'SupportTicketsPerMonth',
#        'Gender', 'WatchlistSize', 'ParentalControl', 'SubtitlesEnabled',
#        'CustomerID', 'Churn'], dtype=object)

# %%
churn_df = pd.DataFrame(churn)
churn_df.describe()
# Out:
#           AccountAge  MonthlyCharges   TotalCharges  ViewingHoursPerWeek  \
# count  243787.000000   243787.000000  243787.000000        243787.000000
# mean       60.083758       12.490695     750.741017            20.502179
# std        34.285143        4.327615     523.073273            11.243753
# min         1.000000        4.990062       4.991154             1.000065
# 25%        30.000000        8.738543     329.147027            10.763953
# 50%        60.000000       12.495555     649.878487            20.523116
# 75%        90.000000       16.238160    1089.317362            30.219396
# max       119.000000       19.989957    2378.723844            39.999723
#
#        AverageViewingDuration  ContentDownloadsPerMonth     UserRating  \
# count           243787.000000             243787.000000  243787.000000
# mean                92.264061                 24.503513       3.002713
# std                 50.505243                 14.421174       1.155259
# ...

# %%
churn_df[churn_df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [AccountAge, MonthlyCharges, TotalCharges, SubscriptionType, PaymentMethod, PaperlessBilling, ContentType, MultiDeviceAccess, DeviceRegistered, ViewingHoursPerWeek, AverageViewingDuration, ContentDownloadsPerMonth, GenrePreference, UserRating, SupportTicketsPerMonth, Gender, WatchlistSize, ParentalControl, SubtitlesEnabled, CustomerID, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
churn_df[churn_df.duplicated]
# Out:
# Empty DataFrame
# Columns: [AccountAge, MonthlyCharges, TotalCharges, SubscriptionType, PaymentMethod, PaperlessBilling, ContentType, MultiDeviceAccess, DeviceRegistered, ViewingHoursPerWeek, AverageViewingDuration, ContentDownloadsPerMonth, GenrePreference, UserRating, SupportTicketsPerMonth, Gender, WatchlistSize, ParentalControl, SubtitlesEnabled, CustomerID, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
def pie_chart(column):
    def fmt(x):
        return '{:.1f}%\n{:.0f}'.format(x, len(churn_df)*x/100)
    plt.title(column)
    plt.pie(
        churn_df[column].value_counts().values,
        labels=churn_df[column].value_counts().index,
        autopct=fmt)
pie_chart('SubscriptionType')

# %%
categorical = ['SubscriptionType', 'PaymentMethod', 'PaperlessBilling', 'ContentType',
       'MultiDeviceAccess', 'DeviceRegistered', 'GenrePreference', 'Gender',
       'ParentalControl', 'SubtitlesEnabled']

# %%
pie_chart(categorical[1])

# %%
pie_chart(categorical[2])

# %%
pie_chart(categorical[3])

# %%
pie_chart(categorical[4])

# %%
pie_chart(categorical[5])

# %%
pie_chart(categorical[6])

# %%
pie_chart(categorical[7])

# %%
pie_chart(categorical[8])

# %%
pie_chart(categorical[9])

# %%
pie_chart('Churn')

# %%
churned = churn_df[churn_df['Churn'] == 1]
stayed = churn_df[churn_df['Churn'] == 0]

# %%
churn_df['SubscriptionType'].value_counts().index
# Out:
# Index(['Standard', 'Basic', 'Premium'], dtype='object', name='SubscriptionType')

# %%
def stacked_bar(column):
       fig, ax = plt.subplots()
       ax.bar(churn_df[column].value_counts().index,
              stayed[column].value_counts(), label='Stayed')
       # Then plot the 'Female' bars on top, starting at the top of the 'Male'
       # bars.
       ax.bar(churn_df[column].value_counts().index,
              churned[column].value_counts(),
              bottom=stayed[column].value_counts(),
              label='Churned')
       ax.set_title(column)
       ax.legend()
stacked_bar(categorical[0])

# %%
stacked_bar(categorical[1])

# %%
stacked_bar(categorical[2])

# %%
stacked_bar(categorical[3])

# %%
stacked_bar(categorical[4])

# %%
stacked_bar(categorical[5])

# %%
stacked_bar(categorical[6])

# %%
stacked_bar(categorical[7])

# %%
stacked_bar(categorical[8])

# %%
stacked_bar(categorical[9])

# %%
churn_df.select_dtypes(include=[int, float]).columns
# Out:
# Index(['AccountAge', 'MonthlyCharges', 'TotalCharges', 'ViewingHoursPerWeek',
#        'AverageViewingDuration', 'ContentDownloadsPerMonth', 'UserRating',
#        'SupportTicketsPerMonth', 'WatchlistSize', 'Churn'],
#       dtype='object')

# %%
import seaborn as sns
sns.heatmap(churn_df.select_dtypes(include=[int, float]).corr())
# Out:
# <Axes: >

# %%
numerical = ['AccountAge', 'MonthlyCharges', 'TotalCharges', 'ViewingHoursPerWeek',
       'AverageViewingDuration', 'ContentDownloadsPerMonth', 'UserRating',
       'SupportTicketsPerMonth', 'WatchlistSize']
plt.title(numerical[0])
sns.histplot(data = churn_df, x = numerical[0], hue = 'Churn', bins=list(range(0,121,2)))
# Out:
# <Axes: title={'center': 'AccountAge'}, xlabel='AccountAge', ylabel='Count'>

# %%
plt.title(numerical[1])
sns.histplot(data = churn_df, x = numerical[1], hue = 'Churn')
# Out:
# <Axes: title={'center': 'MonthlyCharges'}, xlabel='MonthlyCharges', ylabel='Count'>

# %%
plt.title(numerical[2])
sns.histplot(data = churn_df, x = numerical[2], hue = 'Churn', bins=20)
# Out:
# <Axes: title={'center': 'TotalCharges'}, xlabel='TotalCharges', ylabel='Count'>

# %%
plt.title(numerical[3])
sns.histplot(data = churn_df, x = numerical[3], hue = 'Churn')
# Out:
# <Axes: title={'center': 'ViewingHoursPerWeek'}, xlabel='ViewingHoursPerWeek', ylabel='Count'>

# %%
plt.title(numerical[4])
sns.histplot(data = churn_df, x = numerical[4], hue = 'Churn')
# Out:
# <Axes: title={'center': 'AverageViewingDuration'}, xlabel='AverageViewingDuration', ylabel='Count'>

# %%
plt.title(numerical[5])
sns.histplot(data = churn_df, x = numerical[5], hue = 'Churn', bins=list(range(0,51,5)))
# Out:
# <Axes: title={'center': 'ContentDownloadsPerMonth'}, xlabel='ContentDownloadsPerMonth', ylabel='Count'>

# %%
plt.title(numerical[6])
sns.histplot(data = churn_df, x = numerical[6], hue = 'Churn', bins=20)
# Out:
# <Axes: title={'center': 'UserRating'}, xlabel='UserRating', ylabel='Count'>

# %%
plt.title(numerical[7])
sns.histplot(data = churn_df, x = numerical[7], hue = 'Churn', bins=10)
# Out:
# <Axes: title={'center': 'SupportTicketsPerMonth'}, xlabel='SupportTicketsPerMonth', ylabel='Count'>

# %%
plt.title(numerical[8])
sns.histplot(data = churn_df, x = numerical[8], hue = 'Churn', bins=list(range(0,26)))
# Out:
# <Axes: title={'center': 'WatchlistSize'}, xlabel='WatchlistSize', ylabel='Count'>

# %%
plt.hist(np.log(churn_df['TotalCharges']))
# Out:
# (array([  606.,  1583.,  2650.,  5156.,  9261., 17585., 32604., 59917.,
#         72184., 42241.]),
#  array([1.60766722, 2.22433244, 2.84099766, 3.45766288, 4.0743281 ,
#         4.69099332, 5.30765854, 5.92432376, 6.54098898, 7.1576542 ,
#         7.77431942]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import skew
print(skew(churn_df['TotalCharges']))
print(skew(np.log(churn_df['TotalCharges'])))
plt.hist(churn_df['TotalCharges'])
# Out:
# 0.694063444205852
# -1.2726493813827051
# (array([44534., 45124., 43655., 33940., 25962., 19633., 14217.,  9549.,
#          5328.,  1845.]),
#  array([   4.99115435,  242.36442333,  479.7376923 ,  717.11096128,
#          954.48423026, 1191.85749923, 1429.23076821, 1666.60403718,
#         1903.97730616, 2141.35057513, 2378.72384411]),
#  <BarContainer object of 10 artists>)
